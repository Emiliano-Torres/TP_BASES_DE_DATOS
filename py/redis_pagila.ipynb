# %% [markdown]
# ## REDIS

# %%
import redis
r = redis.Redis(host='localhost', port=6379, decode_responses=True)
r.ping()
# Out:
# True

# %%
# datos de sesion se lo pido a chatgpt luego



# ultimas vizualizaciones del usuario
r.hset("ultimas_visualizacion","user1",[('peli1','fechavis1'),('peli1','fechavis1')])
r.hset("ultimas_visualizacion","user2",[('peli1','fechavis1')])
r.hset("ultimas_visualizacion","user3",[('peli1','fechavis1')])
r.hset("ultimas_visualizacion","user4",[('peli1','fechavis1')])


# estado del carrito (porque los quiero separados porque el carrito cambia mas y 
# me gustaria solo grabar cambios de carrito y no de todo el objeto de sesion)
r.hset("carritos","user1",['peli1','peli2'])
r.hset("carritos","user2",['peli1','peli4'])
r.hset("carritos","user3",['peli1'])
r.hset("carritos","user4",['peli3','peli6'])
# Out:
# True
