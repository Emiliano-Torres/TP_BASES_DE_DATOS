# %% [markdown]
# # 4.2 MongoDB - Sistema de Alquiler de Películas
#
# En esta sección decidimos modelar las siguientes dos colecciones:
# - **peliculas**: información general sobre cada película (título, año de lanzamiento, idioma, duración en minutos), con géneros y actores embebidos como arrays. Cuenta además con campos opcionales como director, país de origen, descripción, premios y festivales.
# - **comentarios**: reseñas de usuarios sobre películas, con rating, texto y fecha como campos obligatorios, y campos opcionales como respuestas de otros usuarios, fecha de edición y adjuntos multimedia.

# %% [markdown]
# ## Instalación de dependencias

# %%
# %pip install pymongo faker
# Out:
# Collecting pymongo
#   Downloading pymongo-4.17.0-cp311-cp311-win_amd64.whl.metadata (10 kB)
# Collecting faker
#   Using cached faker-40.23.0-py3-none-any.whl.metadata (16 kB)
# Collecting dnspython<3.0.0,>=2.6.1 (from pymongo)
#   Using cached dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting tzdata (from faker)
#   Downloading tzdata-2026.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Downloading pymongo-4.17.0-cp311-cp311-win_amd64.whl (867 kB)
#    ---------------------------------------- 0.0/867.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/867.9 kB ? eta -:--:--
#    ---------------------------------------- 10.2/867.9 kB ? eta -:--:--
#    - ------------------------------------- 41.0/867.9 kB 393.8 kB/s eta 0:00:03
#    ----- -------------------------------- 122.9/867.9 kB 901.1 kB/s eta 0:00:01
#    -------------------- ------------------- 440.3/867.9 kB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  860.2/867.9 kB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 867.9/867.9 kB 3.6 MB/s eta 0:00:00
# Using cached faker-40.23.0-py3-none-any.whl (2.0 MB)
# Using cached dnspython-2.8.0-py3-none-any.whl (331 kB)
# Downloading tzdata-2026.2-py2.py3-none-any.whl (349 kB)
#    ---------------------------------------- 0.0/349.3 kB ? eta -:--:--
#    --------------------------------------  348.2/349.3 kB 22.5 MB/s eta 0:00:01
#    --------------------------------------- 349.3/349.3 kB 10.9 MB/s eta 0:00:00
# Installing collected packages: tzdata, dnspython, pymongo, faker
# Successfully installed dnspython-2.8.0 faker-40.23.0 pymongo-4.17.0 tzdata-2026.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: C:\Users\Usuario\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Imports

# %%
from pymongo import MongoClient
from faker import Faker
from pprint import pprint
from datetime import datetime, timedelta
import random
import itertools

# Contador global para IDs de películas
pelicula_id_counter = itertools.count(1)

# %% [markdown]
# ## Conexión a MongoDB
#
# Se utiliza una instancia local de MongoDB. El string de conexión es el siguiente (con credenciales anonimizadas):
#
# ```
# mongodb://usuario:contraseña@host:27017/?authSource=admin
# ```

# %%
client = MongoClient("mongodb://admin:secret@localhost:27017/?authSource=admin")
db = client["pagila_mongo"]
print(client.list_database_names())
# Out:
# ['admin', 'config', 'local', 'pagila_mongo']

# %% [markdown]
# ## 4.2.1 Diseño de Colecciones
#
# ### Colección: `peliculas`
#
# Cada documento representa una película con los siguientes campos:
# - `pelicula_id` (int autoincremental, obligatorio)
# - `titulo` (string, obligatorio)
# - `generos` (array de strings, obligatorio) - se modela como array ya que una película puede tener múltiples géneros
# - `actores` (array de strings, obligatorio) - se modela como array ya que una película puede tener varios actores
# - `anio_lanzamiento` (int, obligatorio)
# - `idioma` (string, obligatorio)
# - `duracion_minutos` (int, obligatorio)
# - `pais_origen` (string, opcional)
# - `director` (string, opcional)
# - `premios` (array de strings, opcional)
# - `festivales` (array de strings, opcional)
# - `descripcion` (string, opcional)
#
# ### Colección: `comentarios`
#
# Cada documento representa un comentario de un usuario sobre una película con los siguientes campos:
# - `pelicula_id` (referencia por ID a la colección peliculas)
# - `usuario` (string, obligatorio)
# - `rating` (float entre 1 y 10, obligatorio)
# - `texto` (string, obligatorio)
# - `fecha` (datetime, obligatorio)
# - `fecha_edicion` (datetime, opcional) — solo presente si fue editado
# - `respuestas` (array de objetos (usuario, texto, fecha) opcional) — respuestas de otros usuarios
# - `attachment` (array de objetos(tipo, url)) — adjunto multimedia
#
# ### Diferencias con el modelo relacional
#
# En el modelo relacional, géneros y actores son entidades separadas vinculadas por tablas intermedias (FILM_CATEGORY, FILM_ACTOR), lo que implica joins para acceder a ellos. En MongoDB se optó por embeber ambos como arrays dentro del documento de película, ya que se acceden siempre en conjunto y no tienen sentido de forma independiente en este contexto. Esto elimina la necesidad de joins y simplifica las consultas más frecuentes.
#
# Por otro lado, el modelo documental permite representar de forma natural atributos multivaluados como géneros, actores, premios y festivales, que en el modelo relacional requerirían tablas intermedias adicionales. Del mismo modo, los campos opcionales como director, país de origen, descripción, premios y festivales simplemente no aparecen en el documento cuando no aplican, evitando los valores nulos que generaría un esquema relacional fijo para los mismos datos.
#
# Los comentarios referencian a la película por su pelicula_id, manteniendo la separación entre colecciones dado que son entidades independientes. Además, las respuestas a un comentario se embeben como array dentro del mismo documento, aprovechando la flexibilidad del modelo documental para representar estructuras sin tablas adicionales.

# %% [markdown]
# ## Generación de datos con Faker

# %%
fake = Faker()

GENEROS = ["Acción", "Comedia", "Drama", "Terror", "Ciencia Ficción", 
           "Romance", "Animación", "Documental", "Thriller", "Fantasía"]
IDIOMAS = ["Inglés", "Español", "Francés", "Alemán", "Italiano", "Japonés", "Portugués"]
PAISES = ["Estados Unidos", "Francia", "Reino Unido", "Japón", "España", 
          "Argentina", "Italia", "Alemania", "México", "Corea del Sur"]
FESTIVALES = ["Cannes", "Sundance", "Berlín", "Toronto", "Venecia", "San Sebastián"]
PREMIOS = ["Oscar", "BAFTA", "Globo de Oro", "Palma de Oro", "León de Oro", "Oso de Oro"]

def generar_pelicula():
    tiene_premios = random.random() < 0.3
    tiene_festivales = random.random() < 0.4
    tiene_director = random.random() < 0.8
    tiene_pais = random.random() < 0.9
    tiene_descripcion = random.random() < 0.7

    pelicula = {
        "pelicula_id": next(pelicula_id_counter),
        "titulo": fake.catch_phrase(),
        "generos": random.sample(GENEROS, k=random.randint(1, 3)),
        "actores": [fake.name() for _ in range(random.randint(2, 6))],
        "anio_lanzamiento": random.randint(1970, 2026),
        "idioma": random.choice(IDIOMAS),
        "duracion_minutos": random.randint(70, 210),
    }

    if tiene_pais:
        pelicula["pais_origen"] = random.choice(PAISES)
    if tiene_director:
        pelicula["director"] = fake.name()
    if tiene_premios:
        pelicula["premios"] = random.sample(PREMIOS, k=random.randint(1, 3))
    if tiene_festivales:
        pelicula["festivales"] = random.sample(FESTIVALES, k=random.randint(1, 3))
    if tiene_descripcion:
        pelicula["descripcion"] = fake.paragraph(nb_sentences=2)

    return pelicula


def generar_comentario(pelicula_id):
    tiene_respuestas = random.random() < 0.40
    tiene_attachment = random.random() < 0.3
    fue_editado = random.random() < 0.25

    fecha_base = fake.date_time_between(start_date="-5y", end_date="now")

    comentario = {
        "pelicula_id": pelicula_id,
        "usuario": fake.user_name(),
        "rating": round(random.uniform(1, 10), 1),
        "texto": fake.paragraph(nb_sentences=3),
        "fecha": fecha_base,
    }

    if fue_editado:
        comentario["fecha_edicion"] = fecha_base + timedelta(days=random.randint(1, 30))
    if tiene_respuestas:
        comentario["respuestas"] = [
            {"usuario": fake.user_name(), "texto": fake.sentence(), "fecha": fecha_base + timedelta(days=random.randint(1, 10))}
            for _ in range(random.randint(1, 4))
        ]
    if tiene_attachment:
        tipos_disponibles = ["foto", "video", "archivo"]
        tipos_elegidos = random.sample(tipos_disponibles, k=random.randint(1, len(tipos_disponibles)))
        comentario["attachment"] = {tipo: f"https://storage.pagila.internal/{tipo}/{fake.uuid4()}" for tipo in tipos_elegidos}

    return comentario

def formatear_fechas(doc):
    for campo in ["fecha", "fecha_edicion"]:
        if campo in doc:
            doc[campo] = doc[campo].strftime("%Y-%m-%d %H:%M:%S")
    if "respuestas" in doc:
        for r in doc["respuestas"]:
            if "fecha" in r:
                r["fecha"] = r["fecha"].strftime("%Y-%m-%d %H:%M:%S")
    return doc

# %%
# Limpiar colecciones si ya existen
if "peliculas" in db.list_collection_names():
    db.drop_collection("peliculas")
if "comentarios" in db.list_collection_names():
    db.drop_collection("comentarios")

col_peliculas = db["peliculas"]
col_comentarios = db["comentarios"]

# %% [markdown]
# ## 4.2.2 Operaciones CRUD
#
# ### Inserción en lote - `insert_many`

# %%
# Insertar 150 películas
peliculas = [generar_pelicula() for _ in range(150)]
resultado = col_peliculas.insert_many(peliculas)
ids_peliculas = resultado.inserted_ids

# Mostrar las primeras 3 insertadas
for doc in col_peliculas.find().limit(2):
    pprint(doc)
    print()
# Out:
# {'_id': ObjectId('6a417654165abd4311325520'),
#  'actores': ['Ann Johnson',
#              'Vincent Ellis',
#              'Isaac Forbes',
#              'Joseph Vasquez',
#              'Gina Powell',
#              'Charles Williams'],
#  'anio_lanzamiento': 2009,
#  'descripcion': 'Drug seven five. Fall article sound man.',
#  'director': 'Allison Atkinson',
#  'duracion_minutos': 76,
#  'generos': ['Ciencia Ficción'],
#  'idioma': 'Inglés',
#  'pais_origen': 'España',
#  'pelicula_id': 1,
#  'titulo': 'Enhanced maximized algorithm'}
#
# {'_id': ObjectId('6a417654165abd4311325521'),
#  'actores': ['Brianna Ray',
#              'Andrew Smith',
#              'Jessica Bailey',
#              'Mary Becker',
#              'Marc Francis'],
#  'anio_lanzamiento': 2003,
#  'descripcion': 'Age pull determine quickly matter own reveal teacher.',
#  'director': 'Barbara Graham',
#  'duracion_minutos': 78,
#  'generos': ['Documental', 'Animación', 'Romance'],
#  'idioma': 'Francés',
#  'pais_origen': 'Alemania',
#  'pelicula_id': 2,
#  'titulo': 'Object-based background application'}

# %%
# Insertar entre 1 y 3 comentarios por película
comentarios = []
for pid in ids_peliculas:
    pelicula = col_peliculas.find_one({"_id": pid})
    for _ in range(random.randint(1, 3)):
        comentarios.append(generar_comentario(pelicula["pelicula_id"]))

col_comentarios.insert_many(comentarios)
print(f"Comentarios insertados: {len(comentarios)}")


#Mostrar los primeros 3 insertados
for doc in col_comentarios.find().limit(2):
    pprint(formatear_fechas(doc))
    print()
# Out:
# Comentarios insertados: 298
# {'_id': ObjectId('6a417657165abd43113255b6'),
#  'fecha': '2022-10-25 02:21:01',
#  'pelicula_id': 1,
#  'rating': 6.6,
#  'texto': 'Those address personal property. Yeah performance degree range.',
#  'usuario': 'andersonmelinda'}
#
# {'_id': ObjectId('6a417657165abd43113255b7'),
#  'fecha': '2023-11-15 12:29:59',
#  'fecha_edicion': '2023-12-07 12:29:59',
#  'pelicula_id': 2,
#  'rating': 2.7,
#  'respuestas': [{'fecha': '2023-11-21 12:29:59',
#                  'texto': 'Front area get before successful leader security.',
#                  'usuario': 'melissaharding'},
#                 {'fecha': '2023-11-23 12:29:59',
#                  'texto': 'Up until week majority man.',
#                  'usuario': 'victor82'},
#                 {'fecha': '2023-11-25 12:29:59',
#                  'texto': 'Level what hard truth song.',
#                  'usuario': 'jeff41'}],
#  'texto': 'Natural her natural tax computer. Give education officer oil '
#           'usually cultural difficult. Identify doctor for.',
#  'usuario': 'zimmermancaitlin'}

# %% [markdown]
# ### Inserción individual - `insert_one`

# %%
# Insertar una película individual
nueva_pelicula = {
    "pelicula_id": next(pelicula_id_counter),
    "titulo": "El último fotograma",
    "generos": ["Drama", "Thriller"],
    "actores": ["Laura Gómez", "Carlos Ruiz"],
    "anio_lanzamiento": 2023,
    "idioma": "Español",
    "duracion_minutos": 112,
    "pais_origen": "Argentina",
    "director": "Martín López",
    "premios": ["BAFTA"],
    "festivales": ["San Sebastián", "Toronto"],
    "descripcion": "Una historia de suspenso ambientada en Buenos Aires."
}
res = col_peliculas.insert_one(nueva_pelicula)
pprint(col_peliculas.find_one({"_id": res.inserted_id}))
# Out:
# {'_id': ObjectId('6a417659165abd43113256e0'),
#  'actores': ['Laura Gómez', 'Carlos Ruiz'],
#  'anio_lanzamiento': 2023,
#  'descripcion': 'Una historia de suspenso ambientada en Buenos Aires.',
#  'director': 'Martín López',
#  'duracion_minutos': 112,
#  'festivales': ['San Sebastián', 'Toronto'],
#  'generos': ['Drama', 'Thriller'],
#  'idioma': 'Español',
#  'pais_origen': 'Argentina',
#  'pelicula_id': 151,
#  'premios': ['BAFTA'],
#  'titulo': 'El último fotograma'}

# %% [markdown]
# ### Consultas con filtros y proyecciones

# %%
# Películas lanzadas antes del 2000
resultados = list(col_peliculas.find(
    {"anio_lanzamiento": {"$lt": 2000}},
    {"_id": 0, "titulo": 1, "anio_lanzamiento": 1, "pais_origen":1 }
).limit(5))

for doc in resultados:
    pprint(doc)
    print()
# Out:
# {'anio_lanzamiento': 1989,
#  'pais_origen': 'México',
#  'titulo': 'Front-line eco-centric artificial intelligence'}
#
# {'anio_lanzamiento': 1984,
#  'pais_origen': 'España',
#  'titulo': 'Optimized neutral benchmark'}
#
# {'anio_lanzamiento': 1988,
#  'pais_origen': 'España',
#  'titulo': 'Expanded intermediate standardization'}
#
# {'anio_lanzamiento': 1995,
#  'pais_origen': 'México',
#  'titulo': 'Seamless 5thgeneration pricing structure'}
#
# {'anio_lanzamiento': 1989,
#  'pais_origen': 'Reino Unido',
#  'titulo': 'Sharable impactful artificial intelligence'}

# %%
# Películas de Romance lanzadas entre 2000 y 2010 en Italia o Francia
resultados = list(col_peliculas.find(
    {"$and": [
        {"generos": "Romance"},
        {"anio_lanzamiento": {"$gte": 2000, "$lte": 2010}},
        {"$or": [
            {"pais_origen": "Italia"},
            {"pais_origen": "Francia"}
        ]}
    ]},
    {"_id": 0, "titulo": 1, "anio_lanzamiento": 1, "pais_origen": 1, "descripcion": 1}
).limit(5))

for doc in resultados:
    pprint(doc)
    print()
# Out:
# {'anio_lanzamiento': 2002,
#  'descripcion': 'Middle best nature join. Again attorney body.',
#  'pais_origen': 'Francia',
#  'titulo': 'Decentralized maximized superstructure'}
#
# {'anio_lanzamiento': 2009,
#  'descripcion': 'Another along total play avoid subject.',
#  'pais_origen': 'Italia',
#  'titulo': 'Total context-sensitive Graphic Interface'}
#
# {'anio_lanzamiento': 2006,
#  'descripcion': 'White air window spring could huge.',
#  'pais_origen': 'Italia',
#  'titulo': 'Balanced national ability'}
#
# {'anio_lanzamiento': 2005,
#  'pais_origen': 'Francia',
#  'titulo': 'Quality-focused next generation standardization'}

# %%
# Comentarios con rating mayor a 8
resultados = list(col_comentarios.find(
    {"rating": {"$gte": 8}},
    {"_id": 0, "usuario": 1, "rating": 1, "pelicula_id": 1, "texto": 1, "fecha":1}
).limit(4))

for doc in resultados:
    pprint(formatear_fechas(doc))
    print()
# Out:
# {'fecha': '2023-04-21 13:42:57',
#  'pelicula_id': 8,
#  'rating': 8.3,
#  'texto': 'Small two letter agent. Drop off authority suddenly consider. '
#           'Station base less. Grow charge foreign argue subject.',
#  'usuario': 'nicholas57'}
#
# {'fecha': '2023-03-01 02:21:27',
#  'pelicula_id': 13,
#  'rating': 9.9,
#  'texto': 'Indicate skin company finish. World region state style down '
#           'position. Television goal apply issue join. Hair tonight central '
#           'act thing worry table.',
#  'usuario': 'stephenguerra'}
#
# {'fecha': '2021-11-14 04:58:25',
#  'pelicula_id': 15,
#  'rating': 8.1,
#  'texto': 'Individual recognize must. Discover and sea us learn purpose final '
#           'however.',
#  'usuario': 'monroetheresa'}
#
# {'fecha': '2026-01-10 04:07:55',
#  'pelicula_id': 16,
#  'rating': 8.3,
#  'texto': 'Hair story build truth prove opportunity. Edge just list increase '
#           'property. Response bad church share resource. Cause sometimes '
#           'policy environmental.',
#  'usuario': 'hpierce'}

# %%
# Comentarios con rating menor a 4 y más de 2 respuestas en sus comentarios
resultados = list(col_comentarios.find(
    {
        "rating": {"$lt": 5},
        "$expr": {"$gt": [{"$size": {"$ifNull": ["$respuestas", []]}}, 2]}
    },
    {"_id": 0, "pelicula_id": 1, "usuario": 1, "rating": 1, "respuestas": 1, "fecha":1, "texto":1}
).limit(4))

for doc in resultados:
    pprint(formatear_fechas(doc))
    print()
# Out:
# {'fecha': '2024-12-02 08:54:18',
#  'pelicula_id': 8,
#  'rating': 4.0,
#  'respuestas': [{'fecha': '2024-12-12 08:54:18',
#                  'texto': 'Reach ago type stock way exactly dinner.',
#                  'usuario': 'marytorres'},
#                 {'fecha': '2024-12-04 08:54:18',
#                  'texto': 'Little sell long popular senior sell.',
#                  'usuario': 'pwalker'},
#                 {'fecha': '2024-12-04 08:54:18',
#                  'texto': 'Identify beyond change speech show.',
#                  'usuario': 'marksmith'}],
#  'texto': 'Message final summer instead current worry listen. Number make '
#           'owner side. Class office hour thus suggest continue.',
#  'usuario': 'cochranelizabeth'}
#
# {'fecha': '2025-01-28 08:55:42',
#  'pelicula_id': 19,
#  'rating': 3.4,
#  'respuestas': [{'fecha': '2025-02-03 08:55:42',
#                  'texto': 'End all tell energy itself.',
#                  'usuario': 'trevordickerson'},
#                 {'fecha': '2025-02-03 08:55:42',
#                  'texto': 'Congress arrive prepare.',
#                  'usuario': 'fhoffman'},
#                 {'fecha': '2025-01-29 08:55:42',
#                  'texto': 'Camera who ability stage.',
#                  'usuario': 'williamsmichael'},
#                 {'fecha': '2025-01-29 08:55:42',
#                  'texto': 'Experience plan structure build oil trouble Mrs '
#                           'note.',
#                  'usuario': 'jdavis'}],
#  'texto': 'Six street enter trouble us wish. Region season ago fill rise range '
#           'out. Order often possible speak need.',
#  'usuario': 'narellano'}
#
# {'fecha': '2024-10-26 07:48:49',
#  'pelicula_id': 27,
#  'rating': 3.2,
#  'respuestas': [{'fecha': '2024-10-28 07:48:49',
#                  'texto': 'Seat rise evidence church brother century.',
#                  'usuario': 'jennifer88'},
#                 {'fecha': '2024-11-01 07:48:49',
#                  'texto': 'Hear despite political something.',
#                  'usuario': 'vscott'},
#                 {'fecha': '2024-10-29 07:48:49',
#                  'texto': 'Firm instead happy imagine medical.',
#                  'usuario': 'daniel68'}],
#  'texto': 'Player idea success exactly whom machine. Experience us food image '
#           'eye chair.',
#  'usuario': 'adamsautumn'}
#
# {'fecha': '2025-04-28 02:59:41',
#  'pelicula_id': 30,
#  'rating': 3.0,
#  'respuestas': [{'fecha': '2025-05-05 02:59:41',
#                  'texto': 'Price probably democratic discuss seven same '
#                           'between.',
#                  'usuario': 'smithjessica'},
#                 {'fecha': '2025-05-01 02:59:41',
#                  'texto': 'Thousand air card parent but six.',
#                  'usuario': 'jonesnicole'},
#                 {'fecha': '2025-04-29 02:59:41',
#                  'texto': 'Pm and professor family.',
#                  'usuario': 'joshuarivera'},
#                 {'fecha': '2025-05-02 02:59:41',
#                  'texto': 'Crime well start she fact.',
#                  'usuario': 'tyler97'}],
#  'texto': 'Catch themselves pull operation. Evidence art wait listen best '
#           'quality. Actually become film think.',
#  'usuario': 'crystal97'}

# %% [markdown]
# ### Actualización de documentos

# %% [markdown]
# #### Actualizar uno solo `update_one` peliculas

# %%
# Agregar un premio a una película específica
antes = col_peliculas.find_one({"pelicula_id": 151}, {"_id": 0, "titulo": 1, "premios": 1})

col_peliculas.update_one(
    {"pelicula_id": 151},
    {"$push": {"premios": "Globo de Oro"}}
)

print("Antes:")
pprint(antes)
print("\nDespués:")
pprint(col_peliculas.find_one({"pelicula_id": 151}, {"_id": 0, "titulo": 1, "premios": 1}))
# Out:
# Antes:
# {'premios': ['BAFTA', 'Globo de Oro'], 'titulo': 'El último fotograma'}
#
# Después:
# {'premios': ['BAFTA', 'Globo de Oro', 'Globo de Oro'],
#  'titulo': 'El último fotograma'}

# %% [markdown]
# #### Actualizar varios `update_many` peliculas

# %%
# Marcar todas las películas anteriores a 1990 con un campo "clasico"
antes = list(col_peliculas.find(
    {"anio_lanzamiento": {"$lt": 1990}},
    {"_id": 0, "titulo": 1, "anio_lanzamiento": 1}
).limit(2))

resultado = col_peliculas.update_many(
    {"anio_lanzamiento": {"$lt": 1990}},
    {"$set": {"clasico": True}}
)
print(f"Películas actualizadas: {resultado.modified_count}")

print("\nAntes:")
for doc in antes:
    pprint(doc)

print("\nDespués:")
for doc in col_peliculas.find(
    {"anio_lanzamiento": {"$lt": 1990}},
    {"_id": 0, "titulo": 1, "anio_lanzamiento": 1, "clasico": 1}
).limit(2):
    pprint(doc)
# Out:
# Películas actualizadas: 0
#
# Antes:
# {'anio_lanzamiento': 1989,
#  'titulo': 'Front-line eco-centric artificial intelligence'}
# {'anio_lanzamiento': 1984, 'titulo': 'Optimized neutral benchmark'}
#
# Después:
# {'anio_lanzamiento': 1989,
#  'clasico': True,
#  'titulo': 'Front-line eco-centric artificial intelligence'}
# {'anio_lanzamiento': 1984,
#  'clasico': True,
#  'titulo': 'Optimized neutral benchmark'}

# %% [markdown]
# #### Actualizar uno solo `update_one` comentarios

# %%
# $inc: incrementar el rating de un comentario en 0.5 y modificar la fecha de edición
from datetime import datetime

primer_comentario = col_comentarios.find_one({})
antes = col_comentarios.find_one(
    {"_id": primer_comentario["_id"]},
    {"_id": 0, "rating": 1, "usuario": 1, "pelicula_id": 1, "fecha_edicion": 1, "texto": 1}
)

col_comentarios.update_one(
    {"_id": primer_comentario["_id"]},
    {
        "$inc": {"rating": 0.5},
        "$set": {"fecha_edicion": datetime.now()}
    }
)

despues = col_comentarios.find_one(
    {"_id": primer_comentario["_id"]},
    {"_id": 0, "rating": 1, "usuario": 1, "pelicula_id": 1, "fecha_edicion": 1, "texto": 1}
)
despues["fecha_edicion"] = despues["fecha_edicion"].strftime("%Y-%m-%d %H:%M:%S")

print("Antes:")
pprint(antes)
print("\nDespués:")
pprint(despues)
# Out:
# Antes:
# {'fecha_edicion': datetime.datetime(2026, 6, 28, 16, 33, 50, 346000),
#  'pelicula_id': 1,
#  'rating': 7.1,
#  'texto': 'Those address personal property. Yeah performance degree range.',
#  'usuario': 'andersonmelinda'}
#
# Después:
# {'fecha_edicion': '2026-06-28 16:52:53',
#  'pelicula_id': 1,
#  'rating': 7.6,
#  'texto': 'Those address personal property. Yeah performance degree range.',
#  'usuario': 'andersonmelinda'}

# %% [markdown]
# ### Eliminación de documentos

# %% [markdown]
# #### Eliminar uno solo  `delete_one`

# %%
# Eliminar un comentario con rating menor a 2
comentario_a_eliminar = col_comentarios.find_one({"rating": {"$lt": 2}})
if comentario_a_eliminar:
    print("Comentario a eliminar:")
    pprint(formatear_fechas(comentario_a_eliminar))
    col_comentarios.delete_one({"_id": comentario_a_eliminar["_id"]})
    print("\nComentario eliminado correctamente.")
else:
    print("No se encontró comentario con rating menor a 2.")
# Out:
# No se encontró comentario con rating menor a 2.

# %% [markdown]
# #### Eliminar varios `delete_many`

# %%
# Eliminar todos los comentarios con rating menor a 2 y con respuestas
resultado = col_comentarios.delete_many(
    {"rating": {"$lt": 3}, "respuestas": {"$exists": True}}
)
print(f"Comentarios eliminados: {resultado.deleted_count}")
# Out:
# Comentarios eliminados: 0

# %% [markdown]
# ## 4.2.3 Aggregation Pipelines
#
# ### Pipeline 1: Promedio de rating por película
#
# Este pipeline une las colecciones `comentarios` y `peliculas` para obtener Ids y títulos de películas con su promedio de rating y cantidad de comentarios (ordenadas por promedio de rating de mayor a menor).
#
# | Etapa | Descripción |
# |---|---|
# | `$group` | Agrupa los comentarios por `pelicula_id` y calcula el promedio de rating y la cantidad de comentarios |
# | `$lookup` | Hace un join con la colección `peliculas` para traer el título |
# | `$unwind` | Desanida el array resultado del lookup para acceder al documento de la película |
# | `$project` | Selecciona y renombra los campos a mostrar |
# | `$sort` | Ordena por rating promedio de mayor a menor |
# | `$limit` | Limita la salida para visualización |

# %%
pipeline_rating = [
    # Etapa 1: agrupar comentarios por película y calcular promedio de rating
    {"$group": {
        "_id": "$pelicula_id",
        "rating_promedio": {"$avg": "$rating"},
        "cantidad_comentarios": {"$sum": 1}
    }},
    # Etapa 2: join con colección peliculas para traer el título
    {"$lookup": {
        "from": "peliculas",
        "localField": "_id",
        "foreignField": "pelicula_id",
        "as": "pelicula_info"
    }},
    # Etapa 3: desanidar el array resultado del lookup
    {"$unwind": "$pelicula_info"},
    # Etapa 4: proyectar solo los campos relevantes
    {"$project": {
        "_id":0,
        "pelicula_id": "$_id",
        "titulo": "$pelicula_info.titulo",
        "rating_promedio": {"$round": ["$rating_promedio", 2]},
        "cantidad_comentarios": 1
    }},
    # Etapa 5: ordenar por rating promedio descendente
    {"$sort": {"rating_promedio": -1}},
    {"$limit": 10}
]

resultados = list(col_comentarios.aggregate(pipeline_rating))
for doc in resultados:
    pprint(doc)
    print()
# Out:
# {'cantidad_comentarios': 1,
#  'pelicula_id': 38,
#  'rating_promedio': 9.9,
#  'titulo': 'Cross-group content-based Graphical User Interface'}
#
# {'cantidad_comentarios': 1,
#  'pelicula_id': 100,
#  'rating_promedio': 9.9,
#  'titulo': 'Versatile maximized product'}
#
# {'cantidad_comentarios': 2,
#  'pelicula_id': 131,
#  'rating_promedio': 9.85,
#  'titulo': 'Configurable explicit challenge'}
#
# {'cantidad_comentarios': 1,
#  'pelicula_id': 123,
#  'rating_promedio': 9.8,
#  'titulo': 'Re-contextualized impactful framework'}
#
# {'cantidad_comentarios': 2,
#  'pelicula_id': 95,
#  'rating_promedio': 9.8,
#  'titulo': 'Vision-oriented local instruction set'}
#
# {'cantidad_comentarios': 1,
#  'pelicula_id': 59,
#  'rating_promedio': 9.7,
#  'titulo': 'Extended uniform core'}
#
# {'cantidad_comentarios': 1,
#  'pelicula_id': 121,
#  'rating_promedio': 9.5,
#  'titulo': 'Re-contextualized bandwidth-monitored strategy'}
#
# {'cantidad_comentarios': 2,
#  'pelicula_id': 48,
#  'rating_promedio': 9.4,
#  'titulo': 'Switchable leadingedge attitude'}
#
# {'cantidad_comentarios': 2,
#  'pelicula_id': 122,
#  'rating_promedio': 9.25,
#  'titulo': 'Balanced tertiary structure'}
#
# {'cantidad_comentarios': 3,
#  'pelicula_id': 138,
#  'rating_promedio': 9.03,
#  'titulo': 'Horizontal radical data-warehouse'}

# %% [markdown]
# ### Pipeline 2: Sistema de recomendaciones de películas
#
# Este pipeline devuelve un documento por cada película con toda su información y un array `recomendaciones` con los documentos completos de las películas similares. Se considera similitud por géneros en común (al menos 2), actores en común, o el mismo director.
#
# | Etapa | Descripción |
# |---|---|
# | `$lookup` | Hace un self-join de la colección `peliculas` consigo misma, excluyendo la película actual |
# | `$unwind` | Desanida el array de candidatas para poder operar sobre cada par |
# | `$addFields` | Calcula la cantidad de géneros en común, actores en común, y si el director es el mismo |
# | `$match` | Filtra los pares que cumplan al menos una condición de similitud |
# | `$group` | Reagrupa por película recuperando todos sus campos y armando el array `recomendaciones` con los documentos completos de las películas similares |
# | `$project` | Selecciona los campos relevantes del resultado |
# | `$limit` | Limita la salida para visualización |

# %%
pipeline_similares = [
    # Etapa 1: self-join para comparar cada película con las demás
    {"$lookup": {
        "from": "peliculas",
        "let": {"id_actual": "$pelicula_id", "generos_actuales": "$generos",
                "actores_actuales": "$actores", "director_actual": "$director"},
        "pipeline": [
            {"$match": {"$expr": {"$ne": ["$pelicula_id", "$$id_actual"]}}}
        ],
        "as": "candidatas"
    }},
    # Etapa 2: desanidar candidatas
    {"$unwind": "$candidatas"},
    # Etapa 3: calcular campos de similitud
    {"$addFields": {
        "generos_comunes": {"$size": {"$setIntersection": ["$generos", "$candidatas.generos"]}},
        "actores_comunes": {"$size": {"$setIntersection": ["$actores", "$candidatas.actores"]}},
        "mismo_director": {"$eq": ["$director", "$candidatas.director"]}
    }},
    # Etapa 4: filtrar pares similares
    {"$match": {
        "$or": [
            {"generos_comunes": {"$gte": 2}},
            {"actores_comunes": {"$gte": 1}},
            {"mismo_director": True}
        ]
    }},
    # Etapa 5: agrupar por película y armar array de recomendaciones con doc completo
    {"$group": {
        "_id": "$pelicula_id",
        "titulo": {"$first": "$titulo"},
        "generos": {"$first": "$generos"},
        "actores": {"$first": "$actores"},
        "director": {"$first": "$director"},
        "anio_lanzamiento": {"$first": "$anio_lanzamiento"},
        "idioma": {"$first": "$idioma"},
        "duracion_minutos": {"$first": "$duracion_minutos"},
        "pais_origen": {"$first": "$pais_origen"},
        "premios": {"$first": "$premios"},
        "festivales": {"$first": "$festivales"},
        "recomendaciones": {"$push": "$candidatas"}
    }},
    # Etapa 6: proyectar campos relevantes
    {"$project": {
            "_id": 0,
            "pelicula_id": "$_id",
            "titulo": 1,
            "generos": 1,
            "actores": 1,
            "anio_lanzamiento": 1,
            "idioma": 1,
            "duracion_minutos": 1,
            "director": {"$cond": [{"$gt": ["$director", None]}, "$director", "$$REMOVE"]},
            "pais_origen": {"$cond": [{"$gt": ["$pais_origen", None]}, "$pais_origen", "$$REMOVE"]},
            "premios": {"$cond": [{"$gt": ["$premios", None]}, "$premios", "$$REMOVE"]},
            "festivales": {"$cond": [{"$gt": ["$festivales", None]}, "$festivales", "$$REMOVE"]},
            "recomendaciones": 1
        }},
    {"$limit": 5}
]

resultados = list(col_peliculas.aggregate(pipeline_similares))
for doc in resultados:
    pprint(doc)
    print()
# Out:
# {'actores': ['Aaron Perry',
#              'Andrea Day',
#              'Deborah Hunt',
#              'Joshua Roberts',
#              'Jessica Diaz DVM'],
#  'anio_lanzamiento': 1988,
#  'director': 'Philip Ballard',
#  'duracion_minutos': 93,
#  'generos': ['Ciencia Ficción', 'Documental'],
#  'idioma': 'Alemán',
#  'pais_origen': 'Estados Unidos',
#  'pelicula_id': 101,
#  'recomendaciones': [{'_id': ObjectId('6a417654165abd4311325538'),
#                       'actores': ['Roger Gonzalez',
#                                   'Logan Wilson',
#                                   'Mary Harris'],
#                       'anio_lanzamiento': 2025,
#                       'descripcion': 'He note part religious control clear '
#                                      'investment. Ability lay parent social '
#                                      'development away improve.',
#                       'director': 'Richard Davis',
#                       'duracion_minutos': 195,
#                       'generos': ['Fantasía', 'Documental', 'Ciencia Ficción'],
#                       'idioma': 'Portugués',
#                       'pais_origen': 'Alemania',
#                       'pelicula_id': 25,
#                       'titulo': 'Organic national parallelism'},
#                      {'_id': ObjectId('6a417654165abd4311325586'),
#                       'actores': ['Mrs. Brenda West MD',
#                                   'Christian Mcmillan',
#                                   'Dr. Michael Jones',
#                                   'Samantha Warner',
#                                   'Philip Cross',
#                                   'Michelle Trujillo'],
#                       'anio_lanzamiento': 2020,
#                       'descripcion': 'Him last stuff off discover. Bill power '
#                                      'education.',
#                       'director': 'Samuel Rivera',
#                       'duracion_minutos': 210,
#                       'generos': ['Ciencia Ficción', 'Documental'],
#                       'idioma': 'Francés',
#                       'pais_origen': 'Japón',
#                       'pelicula_id': 103,
#                       'premios': ['BAFTA'],
#                       'titulo': 'Phased well-modulated conglomeration'},
#                      {'_id': ObjectId('6a417654165abd4311325599'),
#                       'actores': ['Anita Klein', 'Jason Gardner'],
#                       'anio_lanzamiento': 2008,
#                       'descripcion': 'Since nice technology century other stop '
#                                      'check. Describe imagine matter treat '
#                                      'lead.',
#                       'director': 'James Munoz',
#                       'duracion_minutos': 150,
#                       'festivales': ['Berlín', 'Toronto', 'Sundance'],
#                       'generos': ['Thriller', 'Ciencia Ficción', 'Documental'],
#                       'idioma': 'Alemán',
#                       'pais_origen': 'Reino Unido',
#                       'pelicula_id': 122,
#                       'titulo': 'Balanced tertiary structure'},
#                      {'_id': ObjectId('6a417654165abd43113255ad'),
#                       'actores': ['Pamela Vasquez',
#                                   'Jeremy Wood',
#                                   'Kathryn Winters'],
#                       'anio_lanzamiento': 2002,
#                       'duracion_minutos': 154,
#                       'festivales': ['Berlín'],
#                       'generos': ['Drama', 'Ciencia Ficción', 'Documental'],
#                       'idioma': 'Alemán',
#                       'pelicula_id': 142,
#                       'titulo': 'Optimized composite secured line'}],
#  'titulo': 'Operative value-added knowledge user'}
#
# {'actores': ['Tammy Ramos', 'Kelsey Richards', 'Jennifer Martin'],
#  'anio_lanzamiento': 2009,
#  'director': 'Chloe Cruz',
#  'duracion_minutos': 90,
#  'festivales': ['Venecia'],
#  'generos': ['Romance', 'Acción'],
#  'idioma': 'Español',
#  'pais_origen': 'Japón',
#  'pelicula_id': 113,
#  'recomendaciones': [{'_id': ObjectId('6a417654165abd4311325543'),
#                       'actores': ['Shawn Duncan',
#                                   'Laura Price',
#                                   'Bryan Chambers',
#                                   'Patricia Thomas',
#                                   'Collin Simmons',
#                                   'Kevin Moreno'],
#                       'anio_lanzamiento': 2014,
#                       'director': 'Cory Clark',
#                       'duracion_minutos': 90,
#                       'generos': ['Romance', 'Acción'],
#                       'idioma': 'Francés',
#                       'pais_origen': 'Italia',
#                       'pelicula_id': 36,
#                       'premios': ['Oscar', 'Oso de Oro', 'León de Oro'],
#                       'titulo': 'Team-oriented leadingedge productivity'},
#                      {'_id': ObjectId('6a417654165abd4311325572'),
#                       'actores': ['Becky Oneal',
#                                   'Michelle Diaz',
#                                   'Derrick Johnson',
#                                   'Andrea Davis',
#                                   'Lynn Howe',
#                                   'Laura Morrison'],
#                       'anio_lanzamiento': 1993,
#                       'descripcion': 'Gas mind threat bank. Matter mouth of '
#                                      'lay.',
#                       'director': 'Carlos Curtis',
#                       'duracion_minutos': 143,
#                       'generos': ['Acción', 'Terror', 'Romance'],
#                       'idioma': 'Alemán',
#                       'pais_origen': 'Estados Unidos',
#                       'pelicula_id': 83,
#                       'titulo': 'Expanded fresh-thinking encryption'},
#                      {'_id': ObjectId('6a417654165abd431132559f'),
#                       'actores': ['Jerry Smith',
#                                   'Glen Hamilton',
#                                   'Rachael Miranda'],
#                       'anio_lanzamiento': 2015,
#                       'descripcion': 'Do reason begin seven involve inside '
#                                      'forget. Along statement us information '
#                                      'control respond stuff.',
#                       'director': 'Ashley Lee',
#                       'duracion_minutos': 113,
#                       'generos': ['Acción', 'Romance'],
#                       'idioma': 'Español',
#                       'pais_origen': 'Alemania',
#                       'pelicula_id': 128,
#                       'titulo': 'Multi-tiered fault-tolerant functionalities'},
#                      {'_id': ObjectId('6a417654165abd43113255a1'),
#                       'actores': ['Mary Martin',
#                                   'Maureen Cochran',
#                                   'Daniel Mcdonald',
#                                   'Kimberly Clark',
#                                   'Chris Maddox',
#                                   'Tyler Estrada'],
#                       'anio_lanzamiento': 1987,
#                       'clasico': True,
#                       'descripcion': 'Item consumer identify pick final you '
#                                      'practice.',
#                       'director': 'Jon Rivera',
#                       'duracion_minutos': 80,
#                       'generos': ['Romance', 'Acción', 'Thriller'],
#                       'idioma': 'Italiano',
#                       'pais_origen': 'Argentina',
#                       'pelicula_id': 130,
#                       'titulo': 'Open-source asynchronous functionalities'}],
#  'titulo': 'Open-source foreground approach'}
#
# {'actores': ['Steven Lamb',
#              'Derrick George',
#              'Jessica Melendez',
#              'Loretta Garcia',
#              'Jacob Rivera'],
#  'anio_lanzamiento': 2010,
#  'director': 'Jose Cooper',
#  'duracion_minutos': 129,
#  'generos': ['Documental', 'Thriller'],
#  'idioma': 'Francés',
#  'pais_origen': 'Japón',
#  'pelicula_id': 123,
#  'premios': ['Oscar', 'Oso de Oro'],
#  'recomendaciones': [{'_id': ObjectId('6a417654165abd431132552a'),
#                       'actores': ['Lacey Wilson PhD',
#                                   'Eric Rogers',
#                                   'Amanda Rodriguez',
#                                   'Joanna Jensen',
#                                   'Vanessa Reyes',
#                                   'Carlos Reed'],
#                       'anio_lanzamiento': 1989,
#                       'clasico': True,
#                       'descripcion': 'Her several trouble area month more bag.',
#                       'director': 'Leonard Hill',
#                       'duracion_minutos': 108,
#                       'generos': ['Drama', 'Thriller', 'Documental'],
#                       'idioma': 'Español',
#                       'pais_origen': 'Reino Unido',
#                       'pelicula_id': 11,
#                       'titulo': 'Sharable impactful artificial intelligence'},
#                      {'_id': ObjectId('6a417654165abd431132558f'),
#                       'actores': ['Louis Fernandez',
#                                   'Veronica King',
#                                   'Jennifer Mcintyre',
#                                   'Janice Meyers'],
#                       'anio_lanzamiento': 1977,
#                       'clasico': True,
#                       'director': 'Michael Johnson',
#                       'duracion_minutos': 180,
#                       'festivales': ['Cannes', 'Venecia'],
#                       'generos': ['Comedia', 'Thriller', 'Documental'],
#                       'idioma': 'Español',
#                       'pais_origen': 'Alemania',
#                       'pelicula_id': 112,
#                       'titulo': 'Multi-lateral content-based software'},
#                      {'_id': ObjectId('6a417654165abd4311325599'),
#                       'actores': ['Anita Klein', 'Jason Gardner'],
#                       'anio_lanzamiento': 2008,
#                       'descripcion': 'Since nice technology century other stop '
#                                      'check. Describe imagine matter treat '
#                                      'lead.',
#                       'director': 'James Munoz',
#                       'duracion_minutos': 150,
#                       'festivales': ['Berlín', 'Toronto', 'Sundance'],
#                       'generos': ['Thriller', 'Ciencia Ficción', 'Documental'],
#                       'idioma': 'Alemán',
#                       'pais_origen': 'Reino Unido',
#                       'pelicula_id': 122,
#                       'titulo': 'Balanced tertiary structure'}],
#  'titulo': 'Re-contextualized impactful framework'}
#
# {'actores': ['Timothy Taylor',
#              'Krista Miller',
#              'Michael Brown',
#              'Pamela Blair',
#              'Ellen Wilson'],
#  'anio_lanzamiento': 2021,
#  'duracion_minutos': 75,
#  'generos': ['Romance', 'Ciencia Ficción', 'Fantasía'],
#  'idioma': 'Italiano',
#  'pais_origen': 'Japón',
#  'pelicula_id': 126,
#  'recomendaciones': [{'_id': ObjectId('6a417654165abd4311325526'),
#                       'actores': ['Edward Johnson',
#                                   'Doris Powell',
#                                   'Lisa Carter',
#                                   'Laurie Mccarty'],
#                       'anio_lanzamiento': 2001,
#                       'descripcion': 'Within popular accept vote age body '
#                                      'meet. Cup about here beautiful rock '
#                                      'raise.',
#                       'duracion_minutos': 170,
#                       'festivales': ['Cannes', 'Venecia'],
#                       'generos': ['Terror'],
#                       'idioma': 'Japonés',
#                       'pais_origen': 'México',
#                       'pelicula_id': 7,
#                       'titulo': 'Programmable directional hub'},
#                      {'_id': ObjectId('6a417654165abd4311325528'),
#                       'actores': ['Dr. Christine Patterson',
#                                   'Kaitlyn Baldwin',
#                                   'Dr. Joseph Nelson'],
#                       'anio_lanzamiento': 1995,
#                       'descripcion': 'Evidence happen already hundred.',
#                       'duracion_minutos': 96,
#                       'generos': ['Documental', 'Acción'],
#                       'idioma': 'Italiano',
#                       'pais_origen': 'México',
#                       'pelicula_id': 9,
#                       'titulo': 'Seamless 5thgeneration pricing structure'},
#                      {'_id': ObjectId('6a417654165abd4311325529'),
#                       'actores': ['Sherry Whitehead',
#                                   'Perry Robinson',
#                                   'Gary Avery',
#                                   'Leah Wall',
#                                   'Sarah Gregory'],
#                       'anio_lanzamiento': 2003,
#                       'duracion_minutos': 161,
#                       'festivales': ['Venecia', 'Cannes'],
#                       'generos': ['Thriller', 'Ciencia Ficción'],
#                       'idioma': 'Italiano',
#                       'pelicula_id': 10,
#                       'titulo': 'De-engineered 24hour moderator'},
#                      {'_id': ObjectId('6a417654165abd4311325537'),
#                       'actores': ['Whitney Adams',
#                                   'Nancy Clark',
#                                   'Frank Schultz',
#                                   'Beth West',
#                                   'John Jackson'],
#                       'anio_lanzamiento': 2001,
#                       'duracion_minutos': 98,
#                       'generos': ['Animación', 'Comedia'],
#                       'idioma': 'Japonés',
#                       'pais_origen': 'Italia',
#                       'pelicula_id': 24,
#                       'titulo': 'Intuitive multi-tasking analyzer'},
#                      {'_id': ObjectId('6a417654165abd4311325538'),
#                       'actores': ['Roger Gonzalez',
#                                   'Logan Wilson',
#                                   'Mary Harris'],
#                       'anio_lanzamiento': 2025,
#                       'descripcion': 'He note part religious control clear '
#                                      'investment. Ability lay parent social '
#                                      'development away improve.',
#                       'director': 'Richard Davis',
#                       'duracion_minutos': 195,
#                       'generos': ['Fantasía', 'Documental', 'Ciencia Ficción'],
#                       'idioma': 'Portugués',
#                       'pais_origen': 'Alemania',
#                       'pelicula_id': 25,
#                       'titulo': 'Organic national parallelism'},
#                      {'_id': ObjectId('6a417654165abd4311325539'),
#                       'actores': ['Charles Allen', 'Jason Gonzalez'],
#                       'anio_lanzamiento': 2010,
#                       'duracion_minutos': 202,
#                       'festivales': ['Berlín'],
#                       'generos': ['Comedia', 'Thriller', 'Ciencia Ficción'],
#                       'idioma': 'Portugués',
#                       'pais_origen': 'Francia',
#                       'pelicula_id': 26,
#                       'titulo': 'Automated neutral process improvement'},
#                      {'_id': ObjectId('6a417654165abd431132553c'),
#                       'actores': ['Beverly Hendrix',
#                                   'Joseph Cabrera',
#                                   'John Farrell',
#                                   'Victoria Price',
#                                   'Christopher Cummings'],
#                       'anio_lanzamiento': 2022,
#                       'duracion_minutos': 95,
#                       'festivales': ['Toronto', 'Venecia'],
#                       'generos': ['Fantasía'],
#                       'idioma': 'Francés',
#                       'pais_origen': 'Francia',
#                       'pelicula_id': 29,
#                       'premios': ['Oscar'],
#                       'titulo': 'Re-engineered needs-based function'},
#                      {'_id': ObjectId('6a417654165abd4311325541'),
#                       'actores': ['Andrea Howard',
#                                   'Terry Velez',
#                                   'Julie Powell',
#                                   'Denise Anderson',
#                                   'Michael Russell',
#                                   'Amanda Allen'],
#                       'anio_lanzamiento': 2013,
#                       'descripcion': 'Notice plant experience. Hope make buy '
#                                      'edge stand article.',
#                       'duracion_minutos': 190,
#                       'festivales': ['Cannes', 'San Sebastián'],
#                       'generos': ['Fantasía', 'Ciencia Ficción'],
#                       'idioma': 'Español',
#                       'pais_origen': 'Reino Unido',
#                       'pelicula_id': 34,
#                       'premios': ['Palma de Oro', 'BAFTA'],
#                       'titulo': 'Focused high-level matrices'},
#                      {'_id': ObjectId('6a417654165abd4311325552'),
#                       'actores': ['Billy Oneal MD',
#                                   'Edward Brown',
#                                   'Debbie Robinson',
#                                   'Matthew Vasquez',
#                                   'Jeremy Stanley'],
#                       'anio_lanzamiento': 1994,
#                       'duracion_minutos': 198,
#                       'generos': ['Ciencia Ficción', 'Thriller', 'Fantasía'],
#                       'idioma': 'Inglés',
#                       'pais_origen': 'Alemania',
#                       'pelicula_id': 51,
#                       'premios': ['Globo de Oro'],
#                       'titulo': 'Enterprise-wide multi-state paradigm'},
#                      {'_id': ObjectId('6a417654165abd4311325556'),
#                       'actores': ['James Sanchez', 'Amy King'],
#                       'anio_lanzamiento': 1982,
#                       'clasico': True,
#                       'descripcion': 'Gas rather coach day assume century '
#                                      'also. Mouth nature find art father.',
#                       'duracion_minutos': 162,
#                       'festivales': ['San Sebastián'],
#                       'generos': ['Romance'],
#                       'idioma': 'Francés',
#                       'pais_origen': 'Francia',
#                       'pelicula_id': 55,
#                       'titulo': 'Open-source human-resource Graphic Interface'},
#                      {'_id': ObjectId('6a417654165abd431132555c'),
#                       'actores': ['Ethan Gonzales',
#                                   'Alan Pineda',
#                                   'Hannah Jones',
#                                   'Daniel Rodriguez',
#                                   'Randall Conley',
#                                   'Kathleen Miller'],
#                       'anio_lanzamiento': 1991,
#                       'descripcion': 'Interest oil wide call.',
#                       'duracion_minutos': 147,
#                       'generos': ['Animación', 'Fantasía'],
#                       'idioma': 'Inglés',
#                       'pais_origen': 'México',
#                       'pelicula_id': 61,
#                       'titulo': 'Programmable regional project'},
#                      {'_id': ObjectId('6a417654165abd431132555e'),
#                       'actores': ['John Williamson',
#                                   'David Rivera',
#                                   'Denise Porter',
#                                   'Pedro May',
#                                   'Gordon Grimes',
#                                   'Holly Carlson'],
#                       'anio_lanzamiento': 1986,
#                       'clasico': True,
#                       'descripcion': 'Later rate glass might left always.',
#                       'duracion_minutos': 90,
#                       'generos': ['Thriller', 'Comedia'],
#                       'idioma': 'Alemán',
#                       'pais_origen': 'Corea del Sur',
#                       'pelicula_id': 63,
#                       'titulo': 'Optimized maximized encoding'},
#                      {'_id': ObjectId('6a417654165abd431132555f'),
#                       'actores': ['Jill Hernandez',
#                                   'Brittany Burton',
#                                   'Cindy Peterson'],
#                       'anio_lanzamiento': 1972,
#                       'clasico': True,
#                       'descripcion': 'Party learn technology home spring. '
#                                      'Music record front system.',
#                       'duracion_minutos': 141,
#                       'generos': ['Ciencia Ficción'],
#                       'idioma': 'Francés',
#                       'pais_origen': 'Corea del Sur',
#                       'pelicula_id': 64,
#                       'titulo': 'Reduced multimedia hardware'},
#                      {'_id': ObjectId('6a417654165abd4311325562'),
#                       'actores': ['Rebecca Moreno', 'Jacob Aguirre'],
#                       'anio_lanzamiento': 2012,
#                       'descripcion': 'Paper reflect house particularly '
#                                      'evidence.',
#                       'director': 'Amanda Cole',
#                       'duracion_minutos': 119,
#                       'generos': ['Fantasía', 'Comedia', 'Ciencia Ficción'],
#                       'idioma': 'Francés',
#                       'pais_origen': 'Corea del Sur',
#                       'pelicula_id': 67,
#                       'premios': ['Palma de Oro', 'BAFTA', 'León de Oro'],
#                       'titulo': 'Cloned solution-oriented array'},
#                      {'_id': ObjectId('6a417654165abd4311325563'),
#                       'actores': ['Ryan Brown',
#                                   'Robert Larson',
#                                   'Tina Le',
#                                   'Jackie Reed',
#                                   'Daniel Shannon',
#                                   'Felicia Kim'],
#                       'anio_lanzamiento': 2025,
#                       'descripcion': 'Sport every ok. Some environment leg lot '
#                                      'ability.',
#                       'duracion_minutos': 171,
#                       'festivales': ['Sundance'],
#                       'generos': ['Thriller'],
#                       'idioma': 'Inglés',
#                       'pais_origen': 'Estados Unidos',
#                       'pelicula_id': 68,
#                       'titulo': 'Profit-focused upward-trending encryption'},
#                      {'_id': ObjectId('6a417654165abd4311325567'),
#                       'actores': ['Sydney Smith',
#                                   'Brian Moore',
#                                   'Tony Simmons',
#                                   'Sara Morris',
#                                   'Annette Velasquez'],
#                       'anio_lanzamiento': 1980,
#                       'clasico': True,
#                       'duracion_minutos': 176,
#                       'generos': ['Animación', 'Comedia', 'Ciencia Ficción'],
#                       'idioma': 'Inglés',
#                       'pelicula_id': 72,
#                       'titulo': 'Realigned transitional help-desk'},
#                      {'_id': ObjectId('6a417654165abd4311325570'),
#                       'actores': ['Jennifer Gillespie', 'Mr. Jeremy Brown III'],
#                       'anio_lanzamiento': 1991,
#                       'duracion_minutos': 165,
#                       'festivales': ['Venecia', 'Berlín', 'Sundance'],
#                       'generos': ['Terror', 'Romance', 'Comedia'],
#                       'idioma': 'Francés',
#                       'pais_origen': 'Italia',
#                       'pelicula_id': 81,
#                       'titulo': 'Robust 6thgeneration ability'},
#                      {'_id': ObjectId('6a417654165abd4311325571'),
#                       'actores': ['Alyssa Collins',
#                                   'Edward Aguilar',
#                                   'Rachel Sullivan',
#                                   'James Ayala',
#                                   'Jack Edwards'],
#                       'anio_lanzamiento': 1970,
#                       'clasico': True,
#                       'descripcion': 'Indicate create long bag far say. Stop '
#                                      'imagine mind past great.',
#                       'duracion_minutos': 206,
#                       'generos': ['Drama'],
#                       'idioma': 'Francés',
#                       'pais_origen': 'Estados Unidos',
#                       'pelicula_id': 82,
#                       'titulo': 'Implemented 6thgeneration flexibility'},
#                      {'_id': ObjectId('6a417654165abd4311325578'),
#                       'actores': ['Eric Stevens',
#                                   'James Hernandez',
#                                   'Nicole Pena'],
#                       'anio_lanzamiento': 1971,
#                       'clasico': True,
#                       'duracion_minutos': 175,
#                       'festivales': ['San Sebastián', 'Sundance'],
#                       'generos': ['Fantasía', 'Comedia', 'Drama'],
#                       'idioma': 'Francés',
#                       'pais_origen': 'Japón',
#                       'pelicula_id': 89,
#                       'premios': ['León de Oro', 'Palma de Oro', 'BAFTA'],
#                       'titulo': 'Triple-buffered intangible analyzer'},
#                      {'_id': ObjectId('6a417654165abd4311325579'),
#                       'actores': ['Jessica Simmons', 'Jon Nunez'],
#                       'anio_lanzamiento': 1996,
#                       'descripcion': 'Point you two then.',
#                       'duracion_minutos': 196,
#                       'generos': ['Terror', 'Acción'],
#                       'idioma': 'Italiano',
#                       'pais_origen': 'Corea del Sur',
#                       'pelicula_id': 90,
#                       'premios': ['Oso de Oro', 'León de Oro', 'BAFTA'],
#                       'titulo': 'Intuitive actuating capability'},
#                      {'_id': ObjectId('6a417654165abd431132557c'),
#                       'actores': ['Geoffrey Young',
#                                   'Brittany Hale',
#                                   'Danielle Mann',
#                                   'Thomas Carter',
#                                   'Joshua Morgan',
#                                   'Jason Morgan'],
#                       'anio_lanzamiento': 1972,
#                       'clasico': True,
#                       'descripcion': 'Occur very rise very sing free avoid.',
#                       'duracion_minutos': 165,
#                       'generos': ['Terror', 'Acción', 'Comedia'],
#                       'idioma': 'Japonés',
#                       'pais_origen': 'Argentina',
#                       'pelicula_id': 93,
#                       'premios': ['Oscar'],
#                       'titulo': 'Optimized grid-enabled standardization'},
#                      {'_id': ObjectId('6a417654165abd431132557f'),
#                       'actores': ['David Avery',
#                                   'Steven Morris',
#                                   'Adam James',
#                                   'Terri Noble'],
#                       'anio_lanzamiento': 1972,
#                       'clasico': True,
#                       'descripcion': 'Operation why often bar.',
#                       'duracion_minutos': 89,
#                       'generos': ['Documental'],
#                       'idioma': 'Español',
#                       'pais_origen': 'Argentina',
#                       'pelicula_id': 96,
#                       'titulo': 'Phased regional process improvement'},
#                      {'_id': ObjectId('6a417654165abd4311325583'),
#                       'actores': ['Cynthia Moore MD',
#                                   'Scott Cooke',
#                                   'Andrea Grant',
#                                   'Amy Brady',
#                                   'Cathy Harvey'],
#                       'anio_lanzamiento': 2025,
#                       'duracion_minutos': 76,
#                       'festivales': ['Cannes'],
#                       'generos': ['Drama'],
#                       'idioma': 'Portugués',
#                       'pais_origen': 'Corea del Sur',
#                       'pelicula_id': 100,
#                       'titulo': 'Versatile maximized product'},
#                      {'_id': ObjectId('6a417654165abd4311325585'),
#                       'actores': ['Taylor Willis',
#                                   'Whitney Peters',
#                                   'Jason Anthony',
#                                   'Douglas Irwin'],
#                       'anio_lanzamiento': 1984,
#                       'clasico': True,
#                       'descripcion': 'Popular author store kind expert car '
#                                      'reveal.',
#                       'director': 'Anthony Lynch',
#                       'duracion_minutos': 92,
#                       'festivales': ['San Sebastián', 'Cannes'],
#                       'generos': ['Thriller', 'Ciencia Ficción', 'Romance'],
#                       'idioma': 'Francés',
#                       'pais_origen': 'Reino Unido',
#                       'pelicula_id': 102,
#                       'titulo': 'Secured 5thgeneration utilization'},
#                      {'_id': ObjectId('6a417654165abd4311325588'),
#                       'actores': ['Amanda Duncan',
#                                   'Anthony Chambers',
#                                   'Brandon Mcintyre',
#                                   'Melissa Watson',
#                                   'William Wang',
#                                   'Sarah Fox'],
#                       'anio_lanzamiento': 2015,
#                       'descripcion': 'Hit including product public law '
#                                      'however.',
#                       'duracion_minutos': 181,
#                       'festivales': ['Sundance', 'Venecia', 'Cannes'],
#                       'generos': ['Comedia', 'Animación', 'Terror'],
#                       'idioma': 'Italiano',
#                       'pelicula_id': 105,
#                       'titulo': 'Expanded actuating open architecture'},
#                      {'_id': ObjectId('6a417654165abd4311325594'),
#                       'actores': ['Christopher Rodriguez',
#                                   'Kiara Simmons',
#                                   'Krista Serrano',
#                                   'Brandon Davis'],
#                       'anio_lanzamiento': 1986,
#                       'clasico': True,
#                       'descripcion': 'Cup north my available. Huge never maybe '
#                                      'gun game reveal put.',
#                       'duracion_minutos': 119,
#                       'festivales': ['Venecia', 'Sundance'],
#                       'generos': ['Documental'],
#                       'idioma': 'Inglés',
#                       'pais_origen': 'Estados Unidos',
#                       'pelicula_id': 117,
#                       'titulo': 'Automated optimal policy'},
#                      {'_id': ObjectId('6a417654165abd4311325597'),
#                       'actores': ['Jordan Cox',
#                                   'Rhonda Barton',
#                                   'Dana Crawford',
#                                   'Nathan Meadows',
#                                   'Samantha Mayo',
#                                   'Priscilla Sparks'],
#                       'anio_lanzamiento': 2017,
#                       'descripcion': 'Everybody everybody political draw '
#                                      'national.',
#                       'duracion_minutos': 120,
#                       'generos': ['Thriller'],
#                       'idioma': 'Español',
#                       'pelicula_id': 120,
#                       'titulo': 'Persevering motivating task-force'},
#                      {'_id': ObjectId('6a417654165abd431132559c'),
#                       'actores': ['Kathryn Schroeder',
#                                   'Cory Gonzales',
#                                   'Casey Miller',
#                                   'Ashley Flores',
#                                   'Lori Nash'],
#                       'anio_lanzamiento': 2005,
#                       'duracion_minutos': 119,
#                       'festivales': ['San Sebastián', 'Venecia'],
#                       'generos': ['Romance', 'Thriller'],
#                       'idioma': 'Inglés',
#                       'pais_origen': 'Francia',
#                       'pelicula_id': 125,
#                       'premios': ['BAFTA'],
#                       'titulo': 'Quality-focused next generation '
#                                 'standardization'},
#                      {'_id': ObjectId('6a417654165abd431132559e'),
#                       'actores': ['Lorraine Everett',
#                                   'Heather Schmidt',
#                                   'Cindy Russell',
#                                   'Kimberly Turner'],
#                       'anio_lanzamiento': 1996,
#                       'descripcion': 'Employee heavy movie tree behavior high '
#                                      'fall. Discover American event expert '
#                                      'lot.',
#                       'duracion_minutos': 173,
#                       'festivales': ['Berlín'],
#                       'generos': ['Acción'],
#                       'idioma': 'Italiano',
#                       'pais_origen': 'Italia',
#                       'pelicula_id': 127,
#                       'titulo': 'Progressive 5thgeneration encoding'},
#                      {'_id': ObjectId('6a417654165abd43113255a6'),
#                       'actores': ['Danny Hooper',
#                                   'Stephanie Lee',
#                                   'Heather Wang'],
#                       'anio_lanzamiento': 1993,
#                       'descripcion': 'Bag project participant everything '
#                                      'factor quality. Why score run wind.',
#                       'director': 'Charles Daugherty',
#                       'duracion_minutos': 148,
#                       'generos': ['Ciencia Ficción', 'Terror', 'Romance'],
#                       'idioma': 'Portugués',
#                       'pais_origen': 'España',
#                       'pelicula_id': 135,
#                       'titulo': 'Business-focused directional ability'},
#                      {'_id': ObjectId('6a417654165abd43113255a9'),
#                       'actores': ['Darren Jordan',
#                                   'Dillon Palmer',
#                                   'Stephen Mcdowell',
#                                   'David Friedman',
#                                   'Sabrina Williamson',
#                                   'Karina Mitchell'],
#                       'anio_lanzamiento': 2011,
#                       'descripcion': 'Sing responsibility close decade.',
#                       'director': 'Vanessa Zuniga',
#                       'duracion_minutos': 189,
#                       'generos': ['Fantasía', 'Ciencia Ficción'],
#                       'idioma': 'Español',
#                       'pais_origen': 'Corea del Sur',
#                       'pelicula_id': 138,
#                       'titulo': 'Horizontal radical data-warehouse'},
#                      {'_id': ObjectId('6a417654165abd43113255aa'),
#                       'actores': ['Sarah Smith', 'Kathleen Jones'],
#                       'anio_lanzamiento': 2017,
#                       'duracion_minutos': 157,
#                       'generos': ['Thriller'],
#                       'idioma': 'Español',
#                       'pais_origen': 'Corea del Sur',
#                       'pelicula_id': 139,
#                       'titulo': 'Integrated logistical time-frame'},
#                      {'_id': ObjectId('6a417654165abd43113255ac'),
#                       'actores': ['Thomas Ellis',
#                                   'Jesus Villarreal',
#                                   'Tyler Cruz',
#                                   'Isaac Fernandez',
#                                   'Valerie Hopkins'],
#                       'anio_lanzamiento': 1973,
#                       'clasico': True,
#                       'descripcion': 'East event pull four scientist behind '
#                                      'thousand. First every politics blood '
#                                      'interesting sister billion.',
#                       'duracion_minutos': 125,
#                       'generos': ['Drama', 'Ciencia Ficción', 'Thriller'],
#                       'idioma': 'Portugués',
#                       'pais_origen': 'Italia',
#                       'pelicula_id': 141,
#                       'titulo': 'Exclusive explicit Local Area Network'},
#                      {'_id': ObjectId('6a417654165abd43113255ad'),
#                       'actores': ['Pamela Vasquez',
#                                   'Jeremy Wood',
#                                   'Kathryn Winters'],
#                       'anio_lanzamiento': 2002,
#                       'duracion_minutos': 154,
#                       'festivales': ['Berlín'],
#                       'generos': ['Drama', 'Ciencia Ficción', 'Documental'],
#                       'idioma': 'Alemán',
#                       'pelicula_id': 142,
#                       'titulo': 'Optimized composite secured line'},
#                      {'_id': ObjectId('6a417654165abd43113255b3'),
#                       'actores': ['Thomas Wallace',
#                                   'Heather Lowe',
#                                   'Eric Massey',
#                                   'Alex Fletcher',
#                                   'Veronica Young',
#                                   'Ronald Beltran'],
#                       'anio_lanzamiento': 2009,
#                       'descripcion': 'Knowledge floor benefit reality '
#                                      'experience.',
#                       'duracion_minutos': 196,
#                       'generos': ['Comedia', 'Thriller', 'Ciencia Ficción'],
#                       'idioma': 'Italiano',
#                       'pais_origen': 'Japón',
#                       'pelicula_id': 148,
#                       'titulo': 'Distributed 24/7 conglomeration'}],
#  'titulo': 'Grass-roots radical hierarchy'}
#
# {'actores': ['Jerry Smith', 'Glen Hamilton', 'Rachael Miranda'],
#  'anio_lanzamiento': 2015,
#  'director': 'Ashley Lee',
#  'duracion_minutos': 113,
#  'generos': ['Acción', 'Romance'],
#  'idioma': 'Español',
#  'pais_origen': 'Alemania',
#  'pelicula_id': 128,
#  'recomendaciones': [{'_id': ObjectId('6a417654165abd4311325543'),
#                       'actores': ['Shawn Duncan',
#                                   'Laura Price',
#                                   'Bryan Chambers',
#                                   'Patricia Thomas',
#                                   'Collin Simmons',
#                                   'Kevin Moreno'],
#                       'anio_lanzamiento': 2014,
#                       'director': 'Cory Clark',
#                       'duracion_minutos': 90,
#                       'generos': ['Romance', 'Acción'],
#                       'idioma': 'Francés',
#                       'pais_origen': 'Italia',
#                       'pelicula_id': 36,
#                       'premios': ['Oscar', 'Oso de Oro', 'León de Oro'],
#                       'titulo': 'Team-oriented leadingedge productivity'},
#                      {'_id': ObjectId('6a417654165abd4311325572'),
#                       'actores': ['Becky Oneal',
#                                   'Michelle Diaz',
#                                   'Derrick Johnson',
#                                   'Andrea Davis',
#                                   'Lynn Howe',
#                                   'Laura Morrison'],
#                       'anio_lanzamiento': 1993,
#                       'descripcion': 'Gas mind threat bank. Matter mouth of '
#                                      'lay.',
#                       'director': 'Carlos Curtis',
#                       'duracion_minutos': 143,
#                       'generos': ['Acción', 'Terror', 'Romance'],
#                       'idioma': 'Alemán',
#                       'pais_origen': 'Estados Unidos',
#                       'pelicula_id': 83,
#                       'titulo': 'Expanded fresh-thinking encryption'},
#                      {'_id': ObjectId('6a417654165abd4311325590'),
#                       'actores': ['Tammy Ramos',
#                                   'Kelsey Richards',
#                                   'Jennifer Martin'],
#                       'anio_lanzamiento': 2009,
#                       'descripcion': 'Yeah mother view sort black.',
#                       'director': 'Chloe Cruz',
#                       'duracion_minutos': 90,
#                       'festivales': ['Venecia'],
#                       'generos': ['Romance', 'Acción'],
#                       'idioma': 'Español',
#                       'pais_origen': 'Japón',
#                       'pelicula_id': 113,
#                       'titulo': 'Open-source foreground approach'},
#                      {'_id': ObjectId('6a417654165abd43113255a1'),
#                       'actores': ['Mary Martin',
#                                   'Maureen Cochran',
#                                   'Daniel Mcdonald',
#                                   'Kimberly Clark',
#                                   'Chris Maddox',
#                                   'Tyler Estrada'],
#                       'anio_lanzamiento': 1987,
#                       'clasico': True,
#                       'descripcion': 'Item consumer identify pick final you '
#                                      'practice.',
#                       'director': 'Jon Rivera',
#                       'duracion_minutos': 80,
#                       'generos': ['Romance', 'Acción', 'Thriller'],
#                       'idioma': 'Italiano',
#                       'pais_origen': 'Argentina',
#                       'pelicula_id': 130,
#                       'titulo': 'Open-source asynchronous functionalities'}],
#  'titulo': 'Multi-tiered fault-tolerant functionalities'}
